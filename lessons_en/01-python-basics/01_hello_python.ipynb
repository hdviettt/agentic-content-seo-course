# %% [markdown]
# # Lesson 1: Hello Python
#
# **What is Python?** A programming language that reads close to English. You write instructions, the computer follows them.
#
# Why Python specifically:
# - It's what AI agents are built with
# - You need to read and modify the code in this project
# - Most popular language for AI and data work
#
# **How to use this notebook:** Press **Shift + Enter** to run each code cell below.

# %%
print("Hello!")

# %% [markdown]
# ## Variables — Labeled Boxes
#
# A **variable** stores data under a name. You pick the name, assign the data with `=`.
#
# The `=` sign means "assign a value" — not the same as "equals" in math.

# %%
name = "Viet"
print(name)

age = 20
print(age)

# %% [markdown]
# ## Strings and f-strings — Inserting Variables into Text
#
# A **string** is text data, always wrapped in quotes: `"..."` or `'...'`.
#
# An **f-string** lets you insert variable values into a string. Just add `f` before the opening quote and put variables inside `{}`.
#
# ```python
# f"Hello {variable_name}"
# ```
#
# This pattern is used everywhere in our project's codebase.

# %%
company = "SEONGON"
role = "AI Leader"

print(f"{name} works at {company}")
print(f"Role: {role}")
print(f"{name} - {role} @ {company}")

# %% [markdown]
# ## Numbers — Basic Math
#
# Python can do math like a calculator:
#
# | Operation      | Symbol | Example       |
# |----------------|--------|---------------|
# | Addition       | `+`    | `5 + 3` = 8   |
# | Subtraction    | `-`    | `10 - 4` = 6  |
# | Multiplication | `*`    | `3 * 7` = 21  |
# | Division       | `/`    | `20 / 4` = 5.0|
#
# You can combine numbers with f-strings for readable output.

# %%
articles = 5
words_per_article = 2000
total_words = articles * words_per_article

print(f"Articles: {articles}")
print(f"Words per article: {words_per_article}")
print(f"Total words: {total_words}")
print(f"If you write {articles} articles/week, that's {articles * 4} per month!")

# %% [markdown]
# ## Mini Exercise
#
# Create your own variables and print a message.
#
# 1. Create a variable `your_name` with your name
# 2. Create a variable `department` with your department
# 3. Create a variable `years` with how many years you've worked
# 4. Use an f-string to print: "[Name] has worked in [department] for [years] years"

# %%
# Exercise: Fill in the blanks (replace ___ with the correct code)

# 1. Create a variable for your company name
company = ___

# 2. Create a variable for the number of employees
employees = ___

# 3. Use an f-string to print a message with both variables
print(f"___ has ___ employees")

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# company = "SEONGON"
# employees = 90
# print(f"{company} has {employees} employees")
# ```
#
# Any text values work for `company` and any number for `employees`. The key is using `{variable_name}` inside the f-string.
# </details>
