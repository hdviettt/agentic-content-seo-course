# %% [markdown]
# # Lesson 19: Claude Code Basics
#
# ## From Understanding to Creating
#
# You've completed 18 lessons. You understand:
# - How LLMs work (Module 2)
# - How to build agents (Module 3)
# - The full production pipeline (Module 4)
# - The complete product: database, CLI, chat (Module 5)
#
# But the goal was never to make you a developer who writes code from scratch.
#
# The goal is for you to **direct AI to develop for you**.
#
# **Claude Code** is how you do that. It's an AI assistant that reads your entire codebase, understands how everything connects, and makes changes based on your instructions.
#
# Analogy: You are the **architect** who designs buildings. Claude Code is the **construction crew** that builds them. You need to understand the blueprint (the codebase) to give good directions — and that's exactly what you've been learning.

# %% [markdown]
# ## What is Claude Code?
#
# Claude Code is a **command-line AI assistant** built by Anthropic. Key differences from ChatGPT:
#
# | Feature | ChatGPT / Web Chat | Claude Code |
# |---------|-------------------|-------------|
# | Sees your code | No (you paste snippets) | Yes (reads entire project) |
# | Edits files | No | Yes (directly modifies code) |
# | Runs commands | No | Yes (tests, installs packages) |
# | Understands context | Limited to conversation | Full project awareness |
# | Verifies work | You check manually | Can run tests itself |
#
# Think of it as: ChatGPT is like texting a consultant. Claude Code is like having the consultant **sit at your desk** with full access to your project.

# %% [markdown]
# ## Installation and CLAUDE.md
#
# ### Installing Claude Code
#
# ```bash
# npm install -g @anthropic-ai/claude-code   # Install globally
# cd your-project-folder                       # Navigate to your project
# claude                                       # Start Claude Code
# ```
#
# (These commands are shown for reference — you don't need to run them now.)
#
# ### CLAUDE.md — Instructions for Claude Code
#
# Just like agents have `instructions`, Claude Code has **CLAUDE.md** — a file in your project root that tells Claude Code how the project works.
#
# This is the EXACT same concept as Lesson 06 (Prompts and Context):
# - Agent `instructions` = system prompt for the agent
# - `CLAUDE.md` = system prompt for Claude Code
#
# Our project already has one. Let's read it:

# %%
import os

claude_md_path = os.path.abspath("../../CLAUDE.md")
with open(claude_md_path, "r", encoding="utf-8") as f:
    content = f.read()

print(f"CLAUDE.md ({len(content)} characters, {len(content.split())} words)\n")
print("First 2000 characters:")
print("=" * 60)
print(content[:2000])
print("\n... (truncated)")

# %% [markdown]
# ## What's in CLAUDE.md?
#
# Our CLAUDE.md contains:
# 1. **Commands** — how to run the project (`python output/chat.py`, `python output/cli.py create "topic"`)
# 2. **Architecture** — how the system is organized (two interfaces, pipeline, agents)
# 3. **Model choices** — which models and why (Claude Sonnet, Grok-4, Opus)
# 4. **Database** — how data is stored
# 5. **Project structure** — what each file does
# 6. **Framework gotchas** — known limitations and workarounds
#
# When you ask Claude Code to make a change, it reads this file first. That's why it can make smart decisions about WHERE to put new code and HOW to follow existing patterns.

# %% [markdown]
# ## The AI Development Workflow
#
# Working with Claude Code follows 5 steps:
#
# ```
# 1. Understand -> 2. Plan -> 3. Implement -> 4. Verify -> 5. Iterate
# ```
#
# This is the same pattern as the agent pipeline:
#
# | AI Dev Workflow | Content Pipeline |
# |----------------|------------------|
# | Understand the problem | Research Agent |
# | Plan the approach | Outline Agent |
# | Implement the solution | Writer Agent |
# | Verify the output | Human review |
# | Iterate if needed | Edit and re-run |
#
# ### The steps:
#
# 1. **Understand** — Claude Code uses "plan mode" to explore the codebase before making changes. Like the Research Agent searching the web first.
# 2. **Plan** — Claude Code designs the approach and shows you for approval. Like the Outline Agent creating structure before writing.
# 3. **Implement** — Claude Code writes the code, creates files, modifies existing ones.
# 4. **Verify** — YOU review the changes using your knowledge from this course. Is the schema right? Is the model choice appropriate? Does it follow existing patterns?
# 5. **Iterate** — If something's off, tell Claude Code what to fix. Repeat until correct.

# %% [markdown]
# ## Key Commands and Modes
#
# | Command / Mode | What it does |
# |----------------|-------------|
# | `claude` | Start Claude Code in your project |
# | Plan mode | Claude Code explores before coding — like the Research Agent |
# | `/help` | See all available commands |
# | `Shift+Tab` | Switch between plan mode and normal mode |
#
# ### Sub-agents
#
# Claude Code delegates to specialized sub-agents for different tasks — just like the **Agno Team** in `chat.py`! The leader (main Claude Code) decides what needs to happen, then delegates to specialists for file reading, code search, terminal commands, etc.

# %% [markdown]
# ## MCPs — Connecting to Documentation
#
# **MCP** (Model Context Protocol) servers give Claude Code access to external knowledge sources.
#
# Example: Our project uses the **Agno framework**. Without an MCP, Claude Code would only know what's in our code files. With the Agno docs MCP connected:
# - Claude Code can look up Agno API methods
# - It knows the latest Agno features and patterns
# - It can check if a function exists before using it
#
# Think of MCPs as giving Claude Code **reference books**. Without them, it works from memory. With them, it can look things up.
#
# Practical example: "I want to add a new tool to the pipeline. With the Agno docs MCP connected, I can just say 'add a Google Search Console tool using the Agno Toolkit pattern' and Claude Code knows the exact API."

# %% [markdown]
# ## Prompting Claude Code Effectively
#
# Everything you learned in Lesson 06 (Prompts and Context) applies here!
#
# ### Bad prompt:
# > "Fix the pipeline"
#
# ### Good prompt:
# > "In output/pipeline.py, the writer agent sometimes generates articles under 1000 words. Add a word count check after the writer step — if the article is under 1000 words, re-run the writer agent with a prompt asking it to expand. Follow the existing error handling pattern with try/except."
#
# The good prompt has:
# - **Specific file** — `output/pipeline.py`
# - **Clear problem** — articles under 1000 words
# - **Specific solution** — add a word count check, re-run if needed
# - **Constraints** — follow existing error handling pattern
#
# ### More examples:
#
# | Task | Bad prompt | Good prompt |
# |------|-----------|------------|
# | Change writing style | "Make articles better" | "In output/agents/builders.py, update writer_agent instructions to write in a casual, conversational tone instead of formal" |
# | Add a feature | "Add keyword tracking" | "Add a target_keyword_density field to ContentOutline in output/agents/schemas.py, and add instructions to the outline agent to calculate keyword density per section" |
# | Debug | "It's broken" | "When running python output/cli.py create 'test', the outline agent returns an error about missing fields. Check output/agents/schemas.py and builders.py for mismatches" |

# %%
# When you ask Claude Code to modify the pipeline, it reads this file first.
# You can do the same thing to understand what it's working with!

pipeline_path = os.path.abspath("../../output/pipeline.py")
with open(pipeline_path, "r", encoding="utf-8") as f:
    pipeline_code = f.read()

print(f"pipeline.py: {len(pipeline_code)} characters, {len(pipeline_code.splitlines())} lines\n")
print("First 40 lines:")
print("=" * 60)
for i, line in enumerate(pipeline_code.splitlines()[:40], 1):
    print(f"  {i:3d} | {line}")

# %% [markdown]
# ## Summary
#
# ### Lesson 19 Summary
#
# What you learned:
# - **Claude Code** reads your entire project and makes changes — like having a developer at your desk
# - **CLAUDE.md** is the system prompt for Claude Code (same concept as agent `instructions`)
# - **5-step workflow**: Understand -> Plan -> Implement -> Verify -> Iterate
# - **MCPs** connect Claude Code to documentation (like giving it reference books)
# - **Good prompts** for Claude Code: be specific about files, problems, solutions, and constraints
# - You are the **architect**, Claude Code is the **builder**. Your understanding from this course is what makes you effective.
#
# **Next lesson:** We'll walk through a real example — adding a new agent to the pipeline using Claude Code.

# %% [markdown]
# ## Exercise
#
# Write Claude Code prompts (as strings — you won't run Claude Code right now) for these tasks:
#
# 1. **Easy**: Change the writer agent's tone from "informative" to "casual and conversational"
# 2. **Medium**: Add a `reading_time_minutes` field to the article database
# 3. **Hard**: Add a DuckDuckGo-based fact-checking step after the writer agent
#
# For each prompt, include: the specific file(s) to modify, what the change should do, and any constraints.

# %%
# Exercise: Write your Claude Code prompts here as Python strings

easy_prompt = """
Your prompt here...
"""

medium_prompt = """
Your prompt here...
"""

hard_prompt = """
Your prompt here...
"""

# Print them to review
for name, prompt in [("Easy", easy_prompt), ("Medium", medium_prompt), ("Hard", hard_prompt)]:
    print(f"=== {name} ===")
    print(prompt)
    print()
