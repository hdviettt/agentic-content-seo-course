# %% [markdown]
# # Why Agentic Content SEO?
#
# Before we dive into building agents, let's talk about **what you're building and why it matters**.
#
# By the end of this course, you'll have a working **multi-agent content pipeline** — a system where specialized AI agents collaborate to produce SEO-optimized articles. You type a topic, and minutes later you get a researched, structured, well-written article with images.
#
# This isn't about replacing SEO professionals. It's about giving them **superpowers at scale**.
#
# Think about it: your agency handles dozens of clients, each needing regular content. A single article takes 4-8 hours of research, writing, and optimization. What if an AI team could do the heavy lifting in 3-5 minutes, and your experts focused on strategy, quality control, and the creative work that actually moves the needle?
#
# That's what you're building here.

# %% [markdown]
# ## How Does This Compare?
#
# | Approach | Speed | Quality | Scalability | Limitation |
# |----------|-------|---------|-------------|------------|
# | Manual writing | 4-8 hours | High (you control it) | Doesn't scale | Time |
# | ChatGPT copy-paste | 5 min | Inconsistent | Manual each time | No research, no structure |
# | Zapier / Make.com | Automated | Low (single prompt) | Breaks easily | One LLM call, no specialization |
# | **Multi-agent pipeline** | **3-5 min** | **High (specialized agents)** | **Batch + parallel** | **Requires understanding** |
#
# The key insight: every other automated approach uses **one AI call** to do everything. Our pipeline uses **four specialized agents**, each doing what it's best at — just like a real content team has a researcher, a strategist, a writer, and an editor.
#
# The "limitation" column is the important part: **this approach requires understanding how to build and customize it**. That's exactly what this course teaches you.

# %% [markdown]
# ## What You'll Build
#
# Here's a preview of the complete system you'll have by Lesson 20:
#
# **Content Pipeline** — 4 specialized agents working in sequence:
# ```
# Research Agent (Claude Sonnet + web search)
#     → Outline Agent (Claude Sonnet + structured output)
#         → Writer Agent (Grok-4 + long-form writing)
#             → Image Agent (Claude Sonnet + image APIs)
# ```
# Each agent uses the **best model for its job** — not one model doing everything.
#
# **Chat Interface** — a conversational team you talk to in natural language:
# - Ask it to create articles, check status, track rankings
# - A team leader (Opus) delegates to specialized members (Sonnet)
# - Chat history persisted so you can pick up where you left off
#
# **Database** — every article tracked from creation to publication:
# - Status at every pipeline step (researching → outlining → writing → review)
# - Version history, keyword rankings, batch processing
#
# **By Lesson 20**, you'll understand every line of code and be able to extend it yourself — add new agents, change models, plug in different APIs.
#
# Now let's start building. First up: your very first AI agent.

# %% [markdown]
# # Lesson 8: Your First AI Agent
#
# ## What is an AI Agent?
#
# An **AI agent** is a program that can **think** and **respond** — like a smart assistant.
#
# Remember from Lesson 5: an LLM predicts the next token based on everything it's seen. When you create an agent, you're giving that LLM a **role** and **instructions** that shape its predictions. That's what happens under the hood every time the agent runs.
#
# Imagine hiring a new employee:
# - You **give them a name** (name)
# - You **choose their brain** (model — here it's Claude)
# - You **write their job description** (instructions — the system prompt from Lesson 6)
# - Then you **assign tasks** and they get to work (run)
#
# That's exactly how an AI agent works!
#
# In this lesson, we'll:
# 1. Create our first AI agent
# 2. Send it a message
# 3. Change the agent's behavior with `instructions`

# %%
# Install required packages
# !python -m pip install agno anthropic python-dotenv

# %% [markdown]
# ## Basic Agent Structure
#
# An agent in Agno has 3 main components:
#
# ```python
# Agent(
#     name="...",          # The agent's name
#     model=Claude(...),    # The brain — which AI model does the thinking
#     instructions=[...],   # Job description — how the agent should behave
# )
# ```
#
# - **`name`**: An identifier for the agent. Like an employee's name.
# - **`model`**: Which AI model does the thinking. We use Claude Sonnet.
# - **`instructions`**: A list of directives. Like writing a job description for a new hire.
#
# > **Cost note:** From this lesson onward, cells that call `agent.run()` make API calls that cost money (~$0.01-0.05 per call for Sonnet). Run each cell once to see the result — avoid re-running unnecessarily.

# %%
from dotenv import load_dotenv
load_dotenv()

from agno.agent import Agent
from agno.models.anthropic import Claude

# Create our first agent!
agent = Agent(
    name="SEO Assistant",
    model=Claude(id="claude-sonnet-4-5-20250929"),
    instructions=["You are an SEO expert. Answer concisely and clearly."],
)

# Send a message to the agent
response = agent.run("What is a meta description? Explain in 2 sentences.")
print(response.content)

# %% [markdown]
# ## Breaking Down the Code
#
# Let's look at the code above piece by piece:
#
# | Code | Meaning |
# |------|--------|
# | `name="SEO Assistant"` | Named our agent "SEO Assistant" |
# | `model=Claude(id="claude-sonnet-4-5-20250929")` | Using Claude Sonnet — fast and smart |
# | `instructions=["..."]` | Directive: "be an SEO expert, answer concisely" |
# | `agent.run("...")` | Send a question and get a response |
# | `response.content` | The agent's reply text |
#
# **Note:** `instructions` is a **list** — you can pass multiple directives.

# %%
# Create another agent with different instructions
content_agent = Agent(
    name="Content Assistant",
    model=Claude(id="claude-sonnet-4-5-20250929"),
    instructions=[
        "You are a content marketing expert.",
        "Answer clearly, suitable for beginners.",
    ],
)

response = content_agent.run("How do you write a compelling article title?")
print(response.content)

# %% [markdown]
# ## Instructions — The Agent's "Job Description"
#
# `instructions` is the **most important** part of an agent. It's like a **job description (JD)** when hiring.
#
# **Good JD** = employee does the right work. **Good instructions** = agent responds the right way.
#
# Examples:
# - `"Answer concisely"` — Agent keeps it short
# - `"Always respond using bullet points"` — Agent uses bullet points
# - `"You are an SEO expert with 10 years of experience"` — Agent gives deep SEO knowledge
#
# Try changing the instructions and see the difference!

# %%
# Agent with specific instructions: ALWAYS use bullet points
agent_bullet = Agent(
    name="Bullet Point Expert",
    model=Claude(id="claude-sonnet-4-5-20250929"),
    instructions=[
        "ALWAYS respond using bullet points.",
        "Each bullet point should be at most 1 sentence.",
    ],
)

# Agent with different instructions: explain like talking to a student
agent_simple = Agent(
    name="Simple Explainer",
    model=Claude(id="claude-sonnet-4-5-20250929"),
    instructions=[
        "Explain concepts as if talking to a middle school student.",
        "Use real-world examples that are easy to understand.",
    ],
)

question = "What are backlinks and why are they important for SEO?"

print("=== BULLET POINT AGENT ===")
r1 = agent_bullet.run(question)
print(r1.content)

print("\n=== SIMPLE EXPLAINER AGENT ===")
r2 = agent_simple.run(question)
print(r2.content)

# %% [markdown]
# ## Lesson 8 Summary
#
# What you learned:
# - **AI Agent** — what it is and how to create one with Agno
# - **3 main components**: `name`, `model`, `instructions`
# - `instructions` shape how the agent responds — like a JD for an employee (and as you learned in Lesson 6, this is the system prompt)
# - Use `agent.run()` to send a message and `response.content` to read the reply
#
# **Next lesson:** We'll give the agent **tools** so it can search the web!

# %% [markdown]
# ## Exercise
#
# Create your own agent with a custom role related to your work. For example:
# - A social media expert
# - A Google Ads specialist
# - A content editor who checks grammar
#
# Give it a `name`, a `model` (use Claude Sonnet), and at least 2 `instructions`.
# Then ask it a question about your work and print the response.

# %%
# Exercise: Fill in the blanks to create a custom SEO agent

from agno.agent import Agent
from agno.models.anthropic import Claude

# Create an agent that acts as an SEO consultant
seo_consultant = Agent(
    name=___,                                    # Give it a name
    model=Claude(id="claude-sonnet-4-5-20250929"),
    instructions=[___],                          # Tell it its role
)

# Ask it a question about SEO
response = seo_consultant.run(___)               # Ask something SEO-related
print(response.content)

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# from agno.agent import Agent
# from agno.models.anthropic import Claude
#
# seo_consultant = Agent(
#     name="SEO Consultant",
#     model=Claude(id="claude-sonnet-4-5-20250929"),
#     instructions=[
#         "You are a senior SEO consultant with 10 years of experience.",
#         "Give actionable, specific advice. Use examples when possible.",
#     ],
# )
#
# response = seo_consultant.run("What are the top 3 things to check in a technical SEO audit?")
# print(response.content)
# ```
# </details>
